# %% [markdown]
# # Life Expectance
# [Data Soure](https://data.worldbank.org/indicator/SP.DYN.LE00.IN)

# %%
# %matplotlib inline

import pandas as pd
import numpy as np

# %%
import os
current_path = os.getcwd()
current_path
# Out:
# 'C:\\Users\\skman\\anaconda3\\Juputer_Learn\\My Work'

# %%
pwd
# Out:
# 'C:\\Users\\skman\\anaconda3\\Juputer_Learn\\My Work'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 448D-E336
#
#  Directory of C:\Users\skman\anaconda3\Juputer_Learn\My Work
#
# 19-10-2024  08:14    <DIR>          .
# 18-10-2024  22:51    <DIR>          ..
# 18-10-2024  22:52    <DIR>          .ipynb_checkpoints
# 18-10-2024  22:49           231,069 API_SP.DYN.LE00.IN_DS2_en_csv_v2_31632.csv
# 18-10-2024  22:43            73,192 First_work.ipynb
# 19-10-2024  08:14             2,078 Using_Jyputer_Notebook.ipynb
#                3 File(s)        306,339 bytes
#                3 Dir(s)  430,346,608,640 bytes free

# %%
import csv

with open("API_SP.DYN.LE00.IN_DS2_en_csv_v2_31632.csv", 'r') as file:
  csvreader = csv.reader(file)
  for row in csvreader:
    print(row)
# Out:
# ['ï»¿"Data Source"', 'World Development Indicators', '']
# []
# ['Last Updated Date', '2024-09-19', '']
# []
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '']
# ...

# %%
pd.read_csv("API_SP.DYN.LE00.IN_DS2_en_csv_v2_31632.csv", header=2)
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                               Indicator Name  Indicator Code       1960  \
# 0    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  64.152000
# 1    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  44.085552
# 2    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  32.535000
# 3    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  37.845152
# ...

# %%
pd.read_csv("API_SP.DYN.LE00.IN_DS2_en_csv_v2_31632.csv", header=2, index_col=[0,1,2,3])
# Out:
#                                                                                                       1960  \
# Country Name                Country Code Indicator Name                          Indicator Code
# Aruba                       ABW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  64.152000
# Africa Eastern and Southern AFE          Life expectancy at birth, total (years) SP.DYN.LE00.IN  44.085552
# Afghanistan                 AFG          Life expectancy at birth, total (years) SP.DYN.LE00.IN  32.535000
# Africa Western and Central  AFW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  37.845152
# Angola                      AGO          Life expectancy at birth, total (years) SP.DYN.LE00.IN  38.211000
# ...                                                                                                    ...
# Kosovo                      XKX          Life expectancy at birth, total (years) SP.DYN.LE00.IN  61.485000
# ...

# %%
card=pd.read_csv("API_SP.DYN.LE00.IN_DS2_en_csv_v2_31632.csv", header=2, index_col=[0,1,2,3])
card
# Out:
#                                                                                                       1960  \
# Country Name                Country Code Indicator Name                          Indicator Code
# Aruba                       ABW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  64.152000
# Africa Eastern and Southern AFE          Life expectancy at birth, total (years) SP.DYN.LE00.IN  44.085552
# Afghanistan                 AFG          Life expectancy at birth, total (years) SP.DYN.LE00.IN  32.535000
# Africa Western and Central  AFW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  37.845152
# Angola                      AGO          Life expectancy at birth, total (years) SP.DYN.LE00.IN  38.211000
# ...                                                                                                    ...
# Kosovo                      XKX          Life expectancy at birth, total (years) SP.DYN.LE00.IN  61.485000
# ...

# %%
card.loc[:,"2015"].dropna()
# Out:
# Country Name                 Country Code  Indicator Name                           Indicator Code
# Aruba                        ABW           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    75.683000
# Africa Eastern and Southern  AFE           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    61.856458
# Afghanistan                  AFG           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    62.659000
# Africa Western and Central   AFW           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    56.195872
# Angola                       AGO           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    60.655000
#                                                                                                         ...
# Kosovo                       XKX           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    78.922000
# ...

# %%
card.plot()
# Out:
# <Axes: xlabel='Country Name'>

# %%
card.index
# Out:
# MultiIndex([(                      'Aruba', 'ABW', ...),
#             ('Africa Eastern and Southern', 'AFE', ...),
#             (                'Afghanistan', 'AFG', ...),
#             ( 'Africa Western and Central', 'AFW', ...),
#             (                     'Angola', 'AGO', ...),
#             (                    'Albania', 'ALB', ...),
#             (                    'Andorra', 'AND', ...),
#             (                 'Arab World', 'ARB', ...),
#             (       'United Arab Emirates', 'ARE', ...),
#             (                  'Argentina', 'ARG', ...),
#             ...
#             (      'Virgin Islands (U.S.)', 'VIR', ...),
#             (                   'Viet Nam', 'VNM', ...),
#             (                    'Vanuatu', 'VUT', ...),
#             (                      'World', 'WLD', ...),
#             (                      'Samoa', 'WSM', ...),
#             (                     'Kosovo', 'XKX', ...),
# ...

# %%
life_expectancy = card.groupby(level=0).first().transpose()
life_expectancy.head()
# Out:
# Country Name  Afghanistan  Africa Eastern and Southern  \
# 1960               32.535                    44.085552
# 1961               33.068                    44.386697
# 1962               33.547                    44.752182
# 1963               34.016                    44.913159
# 1964               34.494                    45.479043
#
# Country Name  Africa Western and Central  Albania  Algeria  American Samoa  \
# 1960                           37.845152   54.439   40.532             NaN
# 1961                           38.164950   55.634   40.516             NaN
# 1962                           38.735102   56.671   39.323             NaN
# 1963                           39.063715   57.844   42.908             NaN
# 1964                           39.335360   58.983   42.788             NaN
#
# Country Name  Andorra  Angola  Antigua and Barbuda  Arab World  ...  \
# 1960              NaN  38.211               61.550   44.972899  ...
# ...

# %%
list(life_expectancy.columns)
# Out:
# ['Afghanistan',
#  'Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
# ...

# %%
l_e_s=life_expectancy[['West Bank and Gaza', 'Switzerland', 'South Africa','Pakistan','India']]
l_e_s.plot()
# Out:
# <Axes: >
