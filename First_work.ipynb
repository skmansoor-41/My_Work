# %%
import numpy as np
import pandas as pd

# %%
a=np.random.rand(100)
a
# Out:
# array([0.02447134, 0.21660229, 0.13299764, 0.54919591, 0.04418837,
#        0.1513355 , 0.65252318, 0.61370848, 0.46653286, 0.91009748,
#        0.18142329, 0.26783117, 0.79736569, 0.08197481, 0.08937238,
#        0.49092729, 0.66626435, 0.67295158, 0.38387203, 0.45429225,
#        0.50228863, 0.65114907, 0.1640502 , 0.38652962, 0.357729  ,
#        0.77843756, 0.99860628, 0.47036842, 0.67665526, 0.58204341,
#        0.94621527, 0.84621973, 0.22260578, 0.26587194, 0.11919061,
#        0.81242687, 0.57282041, 0.33141758, 0.78198923, 0.91958961,
#        0.79785367, 0.65529756, 0.22262473, 0.65983006, 0.04802942,
#        0.32051812, 0.32048363, 0.52327355, 0.39567431, 0.11133287,
#        0.87763437, 0.91808294, 0.51684814, 0.79383872, 0.60867846,
#        0.73280292, 0.03517345, 0.86425947, 0.38736624, 0.85125986,
#        0.94907862, 0.58522568, 0.9475063 , 0.62949178, 0.75950871,
#        0.96478704, 0.81698237, 0.25309462, 0.2876631 , 0.47691431,
# ...

# %%
s=pd.Series(a)
s
# Out:
# 0     0.024471
# 1     0.216602
# 2     0.132998
# 3     0.549196
# 4     0.044188
#         ...
# 95    0.173247
# 96    0.475137
# 97    0.154371
# 98    0.184611
# 99    0.293432
# Length: 100, dtype: float64

# %%
s.values
# Out:
# array([0.02447134, 0.21660229, 0.13299764, 0.54919591, 0.04418837,
#        0.1513355 , 0.65252318, 0.61370848, 0.46653286, 0.91009748,
#        0.18142329, 0.26783117, 0.79736569, 0.08197481, 0.08937238,
#        0.49092729, 0.66626435, 0.67295158, 0.38387203, 0.45429225,
#        0.50228863, 0.65114907, 0.1640502 , 0.38652962, 0.357729  ,
#        0.77843756, 0.99860628, 0.47036842, 0.67665526, 0.58204341,
#        0.94621527, 0.84621973, 0.22260578, 0.26587194, 0.11919061,
#        0.81242687, 0.57282041, 0.33141758, 0.78198923, 0.91958961,
#        0.79785367, 0.65529756, 0.22262473, 0.65983006, 0.04802942,
#        0.32051812, 0.32048363, 0.52327355, 0.39567431, 0.11133287,
#        0.87763437, 0.91808294, 0.51684814, 0.79383872, 0.60867846,
#        0.73280292, 0.03517345, 0.86425947, 0.38736624, 0.85125986,
#        0.94907862, 0.58522568, 0.9475063 , 0.62949178, 0.75950871,
#        0.96478704, 0.81698237, 0.25309462, 0.2876631 , 0.47691431,
# ...

# %%
s.plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline
